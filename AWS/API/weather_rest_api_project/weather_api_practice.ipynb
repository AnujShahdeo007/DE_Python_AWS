# %%
import requests
import pandas as pd 
from datetime import datetime
import os

# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (2.34.2)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/lib/python3.11/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/homebrew/lib/python3.11/site-packages (from requests) (2026.5.20)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anujshahdeo/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/anujshahdeo/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"
API_KEY="131e1d53897c46b8edd37ec180c9e95b"
CITY="Pune"
UNITS="metric"

PARAMS = {
    "q": CITY,
    "appid": API_KEY,
    "units": UNITS
}

# %%
BASE_URL
# Out:
# 'https://api.openweathermap.org/data/2.5/weather'

# %%
print(PARAMS)
# Out:
# {'q': 'Delhi', 'appid': '131e1d53897c46b8edd37ec180c9e95b', 'units': 'metric'}

# %%
response = requests.get(BASE_URL,params=PARAMS,timeout=10)
print(response.status_code)
print(response.url)
# Out:
# 200
# https://api.openweathermap.org/data/2.5/weather?q=Pune&appid=131e1d53897c46b8edd37ec180c9e95b&units=metric

# %%
data=response.json()
print(data)
# Out:
# {'coord': {'lon': 73.8553, 'lat': 18.5196}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 28.56, 'feels_like': 28.9, 'temp_min': 28.56, 'temp_max': 28.56, 'pressure': 1010, 'humidity': 48, 'sea_level': 1010, 'grnd_level': 937}, 'visibility': 10000, 'wind': {'speed': 5.21, 'deg': 263, 'gust': 8.02}, 'clouds': {'all': 83}, 'dt': 1780974252, 'sys': {'type': 2, 'id': 2104163, 'country': 'IN', 'sunrise': 1780964849, 'sunset': 1781012416}, 'timezone': 19800, 'id': 1259229, 'name': 'Pune', 'cod': 200}

# %%
weather_data = {
    "city": data["name"],
    "temperature": data["main"]["temp"],
    "humidity": data["main"]["humidity"],
    "weather": data["weather"][0]["description"],
    "timestamp": datetime.now()
}

# %%
weather_data
# Out:
# {'city': 'Pune',
#  'temperature': 28.56,
#  'humidity': 48,
#  'weather': 'broken clouds',
#  'timestamp': datetime.datetime(2026, 6, 9, 8, 48, 46, 734823)}

# %%
output_folder=
