# %%
x="Sukhjeevan"
y=7
z=x+y
print(z)

# %%
x=True
print(type(x))

# %%
a=10
b=20

# %%
a+b

# %%
a-b

# %%
a*b

# %%
a%b

# %%
a<b

# %%
x=10
y=10

# %%
x==y

# %%
a=10
b=4

# %%
a > 5 and b < 5

# %%
print("hello")
# Out:
# hello

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
#Arithmatic 
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
# Out:
# 13
# 7
# 30

# %%
#Comparision 
a==b
# Out:
# False

# %%
#Conditional 
age=17
if age>=18:
    print("Allowed")
else:
    print("Not allowed")
# Out:
# Not allowed

# %%
#Multiple conditions
score=40
if score>=90:
    print("Grade A")
elif score>=75:
    print("grade B")
elif score>=50:
    print("Grade C")
else :
    print("Fail")
# Out:
# Fail

# %%
Files=["a.csv","b.csv","c.csv","d.csv"]
for file in Files:
	print(file)
# Out:
# a.csv
# b.csv
# c.csv
# d.csv

# %%
count=0
while count<3:
    print(count)
    count=count+1
# Out:
# 0
# 1
# 2

# %%
def addition(a,b):
    return a+b

# %%
addition(10,30)
# Out:
# 40

# %%
lst=[,2,"a",True,1.15]

# %%
lst[0]="new.csv"

# %%
lst
# Out:
# ['new.csv', 2, 'a', True, 1.5]

# %%
for a in lst:
    print(a)
# Out:
# new.csv
# 2
# a
# True
# 1.5

# %%
#methods 
#append()
#remove()
#sort()

lst.append(4)

# %%
lst
# Out:
# ['new.csv', 2, 'a', True, 1.5, 4]

# %%
lst.append("file.csv")

# %%
lst
# Out:
# ['new.csv', 2, 'a', True, 1.5, 4, 'file.csv']

# %%
ids={1,2,3,4,5,5,5,5,5,5}
print(ids)
# Out:
# {1, 2, 3, 4, 5}

# %%
schema=("id","id","id")
print(schema)
# Out:
# ('id', 'id', 'id')
