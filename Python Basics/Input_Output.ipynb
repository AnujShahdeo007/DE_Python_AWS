# %%
name="Priya"
age=10
print(name,age)
# Out:
# Priya 10

# %%
print("hello")
print("hi")
# Out:
# hello
# hi

# %%
# Printing values and variable 
x=10
print(x)
# Out:
# 10

# %%
#Print multiple things 
name="Priya"
age=10
print(name,age)

# Why space in betweeen ?
# - Because print() uses a separator parameter call sep.
# sep=" "
# Out:
# Priya 10

# %%
print(1,2,3, sep=",")
# Out:
# 1,2,3

# %%
print("2026","02","02", sep="/")
# Out:
# 2026/02/02

# %%
print("hello", end="---------------")
print("world")
# Out:
# hello---------------world

# %%
# Priniting with formatting 
name="Priya"
age=10
print(f"My name is {name} and age is {age}")
# Out:
# My name is Priya and age is 10

# %%
a=10
b=20 
print(f"Sum is {a+b}")
# Out:
# Sum is 30

# %%
Name= "Priya"
age=10 

print(f"Hello this my name{name}.      {age}.        this my age ")
# Out:
# Hello this my namePriya.      10.        this my age

# %%
print(f"Square {a}={a**2}")
# You can put 
# math 
# function cell 
# Conditional
# Out:
# Square 10=100

# %%
pi=3.1415926
print(f"Pi value {pi:.4f}")
# Out:
# Pi value 3.1416

# %%
x=5 
print(f"{x:09}")
# Out:
# 000000005

# %%
print(True) #1
print(False)
# Out:
# True
# False

# %%
print(1)
# Out:
# 1

# %%
print(None)
# Out:
# None

# %%
name=input("Enter you name: ") # Prompt - The string you pass into input() is just a prompt message

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
age=int(input("Enter age: "))
print(age+1)
# Out:
# 11

# %%
salaray=float(input("Enter your sala. : "))
#print(salaray*1.10) # 
print(f"sal is {(salaray*1.10):.2f}")
# Out:
# sal is 22.00

# %%
x=input() #"10"
print(x+"5") #105
# Out:
# 105

# %%
#int("10.5") # 
#int("abc") #
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 #int("10.5") #
# ----> 2 int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
x=float(input("Enter float value : "))
print(x+10)
# Out:
# 30.0

# %%
a,b=input("Enter a b ").split()

# %%
a
# Out:
# '10'

# %%
b
# Out:
# '20'

# %%
a,b=10,20

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
# Add two numbers 
a= int(input("Enter a: "))
b= int(input("Enter b: "))
print(f"Sum = {a+b}")
# Out:
# Sum = 30

# %% [markdown]
# Questions
# 1. Average of 3 numbers in one line
# 2. Take a name as input and print --> Hello <name>, welcome to python
# 3. Square and Cube - Take a number as input - Number: <n>, square: <n2>, Cube:<n3>
# 4. Take a gae as input and print - You will be <age+1> years old nect year
# 5. Take a salary as input and print salaary after 10% hike
# 6. Take a number and print - Number <n> is Even
# 7. Take marks and print
#     - Rules
#         - >= 75 - Grade A
#         - 60 -74 - Grade B
#         - 35 - 59 Grade C
#         - < 32 - Fail
#
# 8. Take a amount and print:
#     Final amount after discount: <value>
#     Rule:
#         - >= 5000 -> 20% discount
#         - >= 2000 -> 10%
#         - else - No discount

# %%
# "string {}".format()

name="Priya"
age=20
print("My name is {} and age is {}".format(name,age))
# Out:
# My name is Priya and age is 20

# %%
"""
/*
hdhdhdh
x=10
*/
"""
x=10
