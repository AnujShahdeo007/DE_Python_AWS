# %% [markdown]
# 1. You have a list of numbers.Print whether each element is Even or Odd.
#    numbers=[10,15,20,33]
#
#    Loop goes one number at a time
#    % 2==0 -> Even
#    Otherwise -> Odd
#
# 2. users= ["admin","john","root","mike"]
#     - Block admin users and allow others
#
#     for user in users:
#         if user=="admin" and user=="root":
#             print(user,"is blocked")
#         else:
#             print(user,"is Allowed")
#
# 3. Marks >= 90 Distinction
#     Marks >= 60 -> Pass
#     Else -> Fail
#
# Marks=[95,72,45]
# for m in marks:
#     if m>=60:
#         if m>=90:
#             print(m,"Distinction")
#         else:
#             print(m,"Pass")
#     else:
#         print("Fail)
#
# 4. salries=[1200000,600000,300000]
#
#     Rule:
#         Salary >= 10L -> High tax
#         Salary >= 5 L -> Medium tax
#         Else  -> No tax
#
# for sal in salaries:
#     if sal >= 100000:
#         print("High tax)
#     elif sal>=500000:
#         print("medium")
#     else:
#         print("No tax")
#
# 5. Rule:
#     If Any values is 0 -> System Fail
#     If All values >= 50 -> System Ok
#     Else -> system WARNING
#
#     values=[70,55,0,80]
#     fail=False
#     all_ok=True
#     for v in values:
#         if v == 0:
#             fail=True
#         if v < 50:
#             all_ok=False
#
#     if fail:
#         print("System Fail)
#     elif all_ok:
#         print("System ok")
#     else:
#         print("SYSTEM WARNING)
#
# 6. scores=[65,40.70,55,80]
#
# Rule:
# - Values >= 60 -> Positive vote
# - If postive votes > negative : PASS
# - Fail
#
#
# positive=0
# negative=0
# for s in scores:
#     if s >=60:
#         positive +=1
#     else:
#         negative +=1
# if positive > negative:
#     print("PASS")
# else:
#     print("FAIL")
#
#
# 7. data=[25,75,80,40]
#
# Rule:
#
# - if value < 30 -> Ignore
# - if value >= 30 and < 70 --> MONITOR
# - if value >= 70
#     - if count of >= 70 values >= 2 --> ESCALATE
#     - else --> WARNING
#
# high_count=0
# for d in data:
#     if d <30:
#         print("Ignore")
#     elif d >= 30 and d<=70:
#         print("Monitor")
#     elif d >= 70:
#         if
#
# 8.
#  Rule:
#     - Value must be strictly increasing
#     - If any value breaks order -> Invalid
#     - Else - Valid
#
#     nums=[10,20,25,18,40]
#
# 9. Resouce limitation
#     rule:
#     - Total resouces = 100
#     - consume values one by one
#     - If resource goes negative -> STOP
#
#     requests= [20,30,40,25]
#     resouces = 100
#
# 10. marks= [45,60,70,30,80]
#
#     Rule :
#         - At least 3 values >= 50 -> Accept
#         - Else - reject
#
# 11. Budget Control
#     budget=150
#     expense=[30,40,60,50]
#
#     Rule:
#     - Subtract expense one by one
#     - If budget becomes negative -> STOP
#     - Peint remaning budget after each valid expense
#
# 12. Proformanace Review
#     ratings =[4,3,5,2,4]
#     Rules :
#         - if rating < 3
#             - If more than one rating < 3 -> NO BONUS
#             - ELSE -> REVIEW
#         - ELSE
#             if rating  >= 4 --> BONUS
#             else -> NO BONUS
#
# ratings =[4,3,5,2,4]
# bad_count=0
# for r in ratings:
#     if r < 3:
#
# for r in ratings:
#     if r < 3:
#         if bad_count > 1:
#             print("No bonus")
#         else:
#             print("Review")
#     else:
#         if r>=4:
#             print("BONUS")
#         else:
#             print("NO BONUS)
#
#         bad_count +=1
#
# 13. levels = [100,90,80,85,70]
#     Rules :
#         - If values drop consecutively:
#             - if 3 continious drop -> Critical
#             - Else - Warning
#         - Else -> NORMAL

# %%
users= ["admin","john","root","mike"]
for user in users:
    if user=="admin" or user=="root":
        print(user,"is blocked")
    else:
        print(user,"is Allowed")
# Out:
# admin is blocked
# john is Allowed
# root is blocked
# mike is Allowed

# %%
Marks=[95,72,45,40,89,99,90,10]
for m in Marks:
    if m>=60:
        if m>=90:
            print(m,"Distinction")
        else:
            print(m,"Pass")
    else:
        print("Fail")
# Out:
# 95 Distinction
# 72 Pass
# Fail
# Fail
# 89 Pass
# 99 Distinction
# 90 Distinction
# Fail

# %%
def evaluate_marks(marks):
    for m in Marks:
        if m>=60:
            if m>=90:
                print(m,"Distinction")
            else:
                print(m,"Pass")
        else:
            print("Fail")

# %%
salries=[1200000,600000,300000]
for sal in salries:
    if sal >= 1000000:
        print("High tax")
    elif sal>=500000:
        print("medium")
    else:
        print("No tax")
# Out:
# High tax
# medium
# No tax

# %%
values=[40,40,40,40,40]
fail=False
all_ok=True
for v in values:
    if v == 0:
        fail=True
    if v < 50:
        all_ok=False

if fail:
    print("System Failed")
elif all_ok:
    print("System ok")
else:
    print("SYSTEM WARNING")
# Out:
# SYSTEM WARNING

# %%
scores=[65,40.70,55,80]
positive=0
negative=0
for s in scores:
    if s >=60:
        positive +=1
    else:
        negative +=1 
if positive > negative:
    print("PASS")
else:
    print("FAIL")
# Out:
# FAIL

# %%
# 7. Print numbers 1 to 100 with rules 
#     - divisble by 3 - FIZZ
#     - divisble by 5 - BUZZ
#     - divisble by 7 - JAZZ 

#     - if divible by multiple,concatenate(105- FIZZBUZZJAZZ)
#     - Print the number

# %%
ratings =[4,3,5,4,2,1,2,1,1,1,1,1]
bad_count=0
for r in ratings:
    if r < 3:
        bad_count +=1

for r in ratings:
    if r < 3:
        if bad_count > 1:
            print("No bonus")
        else:
            print("Review")
    else:
        if r>=4:
            print("BONUS")
        else:
            print("NO BONUS")
# Out:
# BONUS
# NO BONUS
# BONUS
# BONUS
# No bonus
# No bonus
# No bonus
# No bonus
# No bonus
# No bonus
# No bonus
# No bonus

# %%
Marks=[89,399,938,938378,8373,938,8,0,2,100]
evaluate_marks(Marks)
# Out:
# 89 Pass
# 399 Distinction
# 938 Distinction
# 938378 Distinction
# 8373 Distinction
# 938 Distinction
# Fail
# Fail
# Fail
# 100 Distinction
