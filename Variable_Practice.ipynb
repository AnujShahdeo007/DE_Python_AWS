# %%
# Assign and print 
x=10 
print(x)

# Notes: In python, Variables are not boxes, They are lables (names) that points to object in Memory.
# Out:
# 10

# %%
print(id(x))  # prints the memory address of the object x is pointing to
# Out:
# 4352125824

# %%
x=20

# %%
print(id(x))  # prints the memory address of the object x is pointing to
# Out:
# 4352126144

# %%
a=10
b=a
print(a,b)
# Out:
# 10 10

# %%
print(id(a)) 
print(id(b))
# Out:
# 4352125824
# 4352125824

# %%
a=99

# %%
print(id(a)) 
print(id(b))
# Out:
# 4352128672
# 4352125824

# %%
# Mutable vs Immutable ( Super Important Concept )

# int,float,bool,str,tuple = Immutable ( Cannot change the object in place )
# list,dict,set = Mutable ( Can change the object in place )  

x=10
x=x+1

# %%
lst=[1,2,3]
lst.append(4) # same list object is modified in place
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
print(x)
x=10
# Out:
# 10

# %%
x=5
x=10
print(x)
# Out:
# 10

# %%
a=10
b=a
print(a,b)
# Out:
# 10 10

# %%
a=10
b=a
a=20
print(a,b)
# Out:
# 20 10
