# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=10.5
y=20
print(x+y)
# Out:
# 30.5

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
first="Hello"
second="world"
print(first + " " +second)
# Out:
# Hello world

# %%
print(hello) #NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(hello) #NameError
#
# NameError: name 'hello' is not defined

# %%
x=10
y=5
print(x>y) #True
# Out:
# True

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
name="Nilam"
city="pune"
print(type(name))
# Out:
# <class 'str'>

# %%
print(name[-5])
# Out:
# N

# %%
s="Python"
s[0]="J" #TypeError


#Why ?.

# String are stored as fixed sequence 
# Changing a charcter means creating a new string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 s="Python"
# ----> 2 s[0]="J" #TypeError
#
# TypeError: 'str' object does not support item assignment

# %%
s="python"
for x in s:
    print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
len(s)
# Out:
# 6

# %%
s="Priyanka"

# %%
s[0]="A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s[0]="A"
#
# TypeError: 'str' object does not support item assignment

# %%
print(s[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(s[10])
#
# IndexError: string index out of range

# %%
print(s["p"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(s["p"])
#
# TypeError: string indices must be integers, not 'str'

# %%
s="India"
print(s[2])
# Out:
# d

# %%
s="python"
print(s[-2])
# Out:
# o

# %%
s="hello"
s[1]="a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 s="hello"
# ----> 2 s[1]="a"
#
# TypeError: 'str' object does not support item assignment
