# %%
# Assign and print 
x=10 
print(x)

# %%
# Update variable (Overwrite)
x=10
x=20
print(x)

# %%
# Multiple assignments
a, b, c = 5, 10, 15
print(a,b,c)

# %%
# Swap value 
a=5
b=10
a, b = b, a
print(a,b)

# %%
price=100
qty=3
total=price*qty
print("Total Price:", total)
