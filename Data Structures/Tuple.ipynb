# %%
t=(1,2,3)

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=1,2,3

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
tu=(5,)

# %%
print(type(tu))
# Out:
# <class 'tuple'>

# %%
pac_t=10,20,30

# %%
a=pac_t

# %%
a
# Out:
# (10, 20, 30)

# %%
a,b,c=pac_t

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
def clean_user(name,city):
        clean_name=name.strip().title()
        clean_city=city.upper()
        status="Valid"
        return clean_name,clean_city,status

# %%
name,city,status=clean_user("priyanka","pune")

# %%
name
# Out:
# 'Priyanka'

# %%
city
# Out:
# 'PUNE'

# %%
status
# Out:
# 'Valid'

# %%
a,_,c=(1,2,3)

# %%
a
# Out:
# 1

# %%
c
# Out:
# 3

# %%
_
# Out:
# 2

# %%
print(a)
# Out:
# 1

# %%
print(c)
# Out:
# 3

# %%
print(_)
# Out:
# 2

# %%
pair=[(1,10),(2,20),(3,30)]

for _,value in pair:
    print(value)
# Out:
# 10
# 20
# 30

# %%
a,b,*c=(1,2,3,4,5)

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
*a,b=(1,2,3,4,5)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b
# Out:
# 5

# %%
a,*middle,c=(1,2,3,4,5)

# %%
middle
# Out:
# [2, 3, 4]

# %%
a
# Out:
# 1

# %%
_,*rest=(10,20,30,40,50)

# %%
rest
# Out:
# [20, 30, 40, 50]

# %%
t=(1,2,3)

t[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 t=(1,2,3)
# ----> 3 t[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(1,2,3)
print(hash(t))
# Out:
# 529344067295497451

# %%
t=([1,2],3)

# %%
t[0].append(99)

# %%
print(t)
# Out:
# ([1, 2, 99], 3)

# %%
a=(1,2,3)
A,b,c,d=a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 a=(1,2,3)
# ----> 2 A,b,c,d=a
#
# ValueError: not enough values to unpack (expected 4, got 3)
