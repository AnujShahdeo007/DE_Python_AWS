# %%
text="PYTHON"
print(text[0])
# Out:
# P

# %%
print(text[0:3])
# Out:
# PYT

# %%
print(text[0:6:2])
# Out:
# PTO

# %% [markdown]
# - Medium Level
# - Tough Level
# - Trick Questions

# %%
s="DataEngineering" 
# DataE 
# ring

# %%
print(s[-4:])
# Out:
# ring

# %%
text="PYTHON"
# YTHO
print(text[1:5])
# Out:
# YTHO

# %%
s="DataScience" # DataecneicS

# mid=len(s)//2
# print(s[mid::] [:mid])
mid = len(s) // 2
print(s[:mid] [::-1] + s[mid:]) # Reverse only the First Half
print(s[:mid] + s[mid:][::-1])
print(s[:4]+s[4:][::-1])
#print(s[:mid] + s[mid:] [::-1]) 
# sthalf = s[:mid]
# ndhalf = s[mid:]
# reverse = ndhalf[::-1]
# result = sthalf + reverse

# print(result)
# Out:
# SataDcience
# DataSecneic
# DataecneicS

# %%
reverse
# Out:
# 'ecneic'

# %%
s="Python"
# Print Middle chacter(s) #th

# %%
s="DataEngineering" # aEngineeringDat
# Move first 3 chacters to the end

# %%
# Reverse Each half seperately
s="abcdefgh"
# dcbahgfe
mid = len(s) // 2
print(s[:mid][::-1] + s[mid:][::-1])
# Out:
# dcbahgfe

# %%
text="PYTHON"

# %%
text[0]="J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 text[0]="J"
#
# TypeError: 'str' object does not support item assignment

# %%
new_text="J"+text[1:]
print(new_text)
# Out:
# JYTHON

# %%
print("Hi" *3)
# Out:
# HiHiHi

# %%
text="python"

for ch in text:
    print(ch)
# Out:
# p
# y
# t
# h
# o
# n

# %%
print(text.center(100))
# Out:
#                                                python

# %%
print("42".zfill(5))
# Out:
# 00042

# %%
text="ababababababababababababababab"
print(text.count("a"))
# Out:
# 15

# %%
words=["Python","Spark","Aws"]
print("-".join(words))
# Out:
# Python-Spark-Aws

# %%
table=str.maketrans("ae","12")
print("apple".translate(table))
# {'a':'1','e':'2'}
# Out:
# 1ppl2

# %%
text="hello"
print(text.partition(" "))
# Out:
# ('hello', '', '')

# %%
text="I like Java"
print(text.replace("Java","Python"))
# Out:
# I like Python

# %%
text="unhappy"
print(text.removeprefix("un"))
# Out:
# happy

# %%
text="data.csv"
print(text.removesuffix(".csv"))
# Out:
# data

# %%
text="Python Spark SQl"
print(text.split())
# Out:
# ['Python', 'Spark', 'SQl']

# %%
text="apple,banana,mango"
print(text.split(","))
# Out:
# ['apple', 'banana', 'mango']

# %%
text="one two three four"
print(text.split(" ",1))
# Out:
# ['one', 'two three four']

# %%
text="Hello\nWord\nPython"
print(text)
# Out:
# Hello
# Word
# Python

# %%
print(text.splitlines())
# Out:
# ['Hello', 'Word', 'Python']

# %%
text="Python programming"
print(text.endswith("Python",6,))
# Out:
# False

# %%
text="     Python   Programming     "
print(text.strip())
# Out:
# Python   Programming

# %%
text="########Python########"
print(text.strip("#"))
# Out:
# Python

# %%
text="xyxPythonxyx"
print(text.strip("xyx"))
# Out:
# Python

# %%
name=input("Enter name: ").strip()

# %%
name
# Out:
# 'abababab'

# %%
table=str.maketrans(" "," ","aeiou")
print("education".translate(table))
# Out:
# dctn

# %% [markdown]
# # Questions
#
# Prob 1:
#
# You are givem a list of emails
# write a function to return only valid emails
#
# conditions :
#
# must conatins "@"
# must end with .com or .org
#
# example :
#
# ["hello#gmail.com,"hello@yahoo","test@company.org","wrongemail.com"]
#
# output
#
# [hello#gmail.com,test@company.org]
#
#
# list
# string functions
# loop
# function
#
#
#
# # prob 2: Given sentance, count frequnecy of each word
#
# text="python spark python sql spark python"
#
# expected:
#
# {
#     'python':3
#     'spark':2
#     'sql':1
# }
#
# Without using inbult function
# split
# dictionary
# loops
#
# # prob 3 : Given list of full names, Genarte username
#
#     Rule: firstname + last 3 digits of phone
#
#     data=[
#         ("Rahul sharma",'98765432210"),
#         ("Asshis kumar","9123486700)
#     ]
#
#     Expected output :
#
#     ['Rahul210','Asshis700']
#
#
#     tuple
#     string
#     slicing
#     loops
#
# # Prob 4 : Remove duplicate words '
#
# text="Python spark python sql spark"
#
# Output :
#
# python,spark,sql
#
# Concepts
#
# split
# list
# set
# join
#
# # 5 Input : "1234567812345678"
#
# Output
#
# ************5678
#
# # Medium Level
#
# # 6 Log File Ananlyzer

# %%
text = "python spark python sql spark python"
freq = {}
for word in text.split():
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# {'python': 3, 'spark': 2, 'sql': 1}

# %%
text = "Python spark python sql spark"
words = text.lower().split()   
unique = set(words) 
result = " ".join(unique)      
print(result)
# Out:
# python spark sql

# %%
data=[
        ("Rahul sharma","98765432210"),
        ("Asshis kumar","9123486700")
    ]
usernames = []
for name, phone in data:
    first = name.split()[0]  
    #print(first)    
    lastt = phone[-3:]  
    #print(lastt)        
    usernames.append(first+ lastt)
print(usernames)
# Out:
# ['Rahul210', 'Asshis700']

# %%
text = "python spark python sql spark"

Lst= text.split()   
uni = []
for i in Lst:
    if i not in unique:
        uni.append(i)
print(result)
# Out:
# python spark sql
