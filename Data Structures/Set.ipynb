# %%
s={5,1,3,4,2}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(s[0])
#
# TypeError: 'set' object is not subscriptable

# %%
print(hash(10))
# Out:
# 10

# %%
print(hash(20))
# Out:
# 20

# %%
print(hash("apple"))
# Out:
# 7516855012142542455

# %%
print(hash("banana"))
# Out:
# 4071225626116538992

# %%
print(hash("apple"))
# Out:
# 7516855012142542455

# %%
s={23,15,9}

# %% [markdown]
# Python takes each element and finds its hash
#
# hash(value)
#
# hash(23) =23
# hash(15)=15
# hash(9)=9
#
# # For small integer, hash usually return same number
#
# box 0 box 1 box 3 box 4 box 5 box 6 box 7 box 8 box 9 box 10
#
#
# box_index= hash(value) % total_boxes
#
# 23 - 3
# 15 - 5
# 9 - 9

# %%
values=[23,15,9]
total_boxex=10 

for v in values:
    h=hash(v)
    box=h%total_boxex
    print(f"value={v}, hash={h},box={box}")
# Out:
# value=23, hash=23,box=3
# value=15, hash=15,box=5
# value=9, hash=9,box=9

# %%
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
s=set()
print(type(s))
# Out:
# <class 'set'>

# %%
nums={1,2,2,3,4,4}
print(nums)
# Out:
# {1, 2, 3, 4}

# %%
s={1,2,3,5,8,9,7,6}
#print(s[0])

# %%
for item in s:
    print(item)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9

# %%
s={1,2}

s.add(3) 
print(s)
# Out:
# {1, 2, 3}

# %%
# add 
s={1,2,3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s.add(4)

# %%
print(s)
# Out:
# {1, 2, 3, 4}

# %%
# update

s={1,2}
s.update([1,2,3,4])
print(s)
# Out:
# {1, 2, 3, 4}

# %%
today_users={101,102}
new_users=[102,103,104]
today_users.update(new_users)
print(today_users)
# Out:
# {104, 101, 102, 103}

# %%
s={10,20,30}
print(s.pop())
print(s)
# Out:
# 10
# {20, 30}

# %%
pending_task={"Email_client","Fix_bug","Update_report","Call_Manager"}
print("Before removing", pending_task)

removed_task=pending_task.pop()

print("removed_task",removed_task)

print("After removing",pending_task)
# Out:
# Before removing {'Fix_bug', 'Email_client', 'Update_report', 'Call_Manager'}
# removed_task Fix_bug
# After removing {'Email_client', 'Update_report', 'Call_Manager'}

# %%
files_to_process={"file1.csv","file2.csv","file3.csv","file4.csv","file5.csv"}
while files_to_process:
    file=files_to_process.pop()
    print("processing :", file)

print(files_to_process)
# Out:
# processing : file3.csv
# processing : file1.csv
# processing : file5.csv
# processing : file4.csv
# processing : file2.csv
# set()

# %% [markdown]
# You are building a simple Task schduler for a data engineering team:
#
#     Every day you get task from multiple sources:
#         - Jira export
#         - Email request
#         - Monitoring alert
#
#     These task are coming as lists and may have duplicates :
#
#         You want to :
#
#             - Collect task (list)
#             - Remove duplicates
#             - Keep a unique pending task pool
#             - Assihn task one by one to engineers
#             - Add new task anytime
#
#
# jira_tasks=[
#     "Fix ETL failure",
#     "Optimize spark job"
#     "Update Redshift Table"
#     " Fix ETl failure"          # Duplicate
# ]
#
# email_tasks=[
#     "Create new AWS glue job"
#     "Optimize spark job",       # Duplicate
#     "Add data quality checks"
# ]
#
# monitoring_alerts=[
#     "restart kakfa consumer",
#     "Fix ETL failure",          # Duplicate
#     "Investing s3 deply"
# ]
